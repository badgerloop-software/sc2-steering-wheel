# %%
from PIL import Image
from PIL import GifImagePlugin

# %%
imageObj = Image.open("disint.gif")

# %%
imageObj.is_animated
# Out:
# True

# %%
imageObj.n_frames
# Out:
# 14

# %%
from wand.image import Image
with Image(filename="disint.gif") as img:
    img.coalesce()
    img.save(filename="frame%02d.bmp")

# %%
import convertIMGtoCarray

# %%
convertIMGtoCarray.convert_gif_to_rgb332_frames("disint.gif", "animation", max_frames = 3)
# Out:
# Processing GIF with 3 frames, dimensions: 220x211
# Processed frame 1/3
# Processed frame 2/3
# Processed frame 3/3
# Successfully created header file: animation.h
# Total size: 139260 bytes
