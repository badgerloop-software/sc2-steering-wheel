# %%
from PIL import Image
from PIL import GifImagePlugin

# %%
imageObj = Image.open("disint.gif")

# %%
imageObj.is_animated
# Out:
# True

# %%
imageObj.n_frames
# Out:
# 14

# %% [markdown]
# PIP package used is-- pip install Wand ImageMagick
# install MagickWand from https://imagemagick.org/script/download.php#windows

# %%
from wand.image import Image
with Image(filename="disint.gif") as img:
    img.coalesce()
    # img.save(filename="frame%02d.bmp")

# %%
import convertIMGtoCarray
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import convertIMGtoCarray
#
# File c:\Users\adity\sc2-steering-wheel\convertIMGtoCarray.py:9
#       7 import numpy as np
#       8 from PIL import Image
# ----> 9 import matplotlib.pyplot as plt
#      10 import sys
#      13 ## Convert video to RGB332 format with all frames stacked vertically
#      14 # Process each frame of an animated video into RGB332 format
#      15 # Generate a C header file with frames stacked in a single array
#    (...)
#      20 # @param max_frames Maximum number of frames to process (None for all)
#      21 # @param rotate_k Number of 90 degree rotations to apply to each frame (0, 1, 2, or 3)
#
# File c:\Users\adity\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\pyplot.py:55
#      53 from cycler import cycler  # noqa: F401
#      54 import matplotlib
# ---> 55 import matplotlib.colorbar
#      56 import matplotlib.image
#      57 from matplotlib import _api
#
# File c:\Users\adity\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\colorbar.py:19
#      16 import numpy as np
#      18 import matplotlib as mpl
# ---> 19 from matplotlib import _api, cbook, collections, cm, colors, contour, ticker
#      20 import matplotlib.artist as martist
#      21 import matplotlib.patches as mpatches
#
# File c:\Users\adity\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\collections.py:20
#      17 import numpy as np
#      19 import matplotlib as mpl
# ---> 20 from . import (_api, _path, artist, cbook, cm, colors as mcolors, _docstring,
#      21                hatch as mhatch, lines as mlines, path as mpath, transforms)
#      22 from ._enums import JoinStyle, CapStyle
#      25 # "color" is excluded; it is a compound setter, and its docstring differs
#      26 # in LineCollection.
#
# File c:\Users\adity\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\lines.py:17
#      14 from .artist import Artist, allow_rasterization
#      15 from .cbook import (
#      16     _to_unmasked_float_array, ls_mapper, ls_mapper_r, STEP_LOOKUP_MAP)
# ---> 17 from .markers import MarkerStyle
#      18 from .path import Path
#      19 from .transforms import Bbox, BboxTransformTo, TransformedPath
#
# File c:\Users\adity\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\markers.py:147
#     142 # special-purpose marker identifiers:
#     143 (TICKLEFT, TICKRIGHT, TICKUP, TICKDOWN,
#     144  CARETLEFT, CARETRIGHT, CARETUP, CARETDOWN,
#     145  CARETLEFTBASE, CARETRIGHTBASE, CARETUPBASE, CARETDOWNBASE) = range(12)
# --> 147 _empty_path = Path(np.empty((0, 2)))
#     150 class MarkerStyle:
#     151     """
#     152     A class representing marker types.
#     153
#    (...)
#     164         The supported fillstyles.
#     165     """
#
# File c:\Users\adity\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\path.py:152, in Path.__init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#     150 self._codes = codes
#     151 self._interpolation_steps = _interpolation_steps
# --> 152 self._update_values()
#     154 if readonly:
#     155     self._vertices.flags.writeable = False
#
# File c:\Users\adity\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\path.py:203, in Path._update_values(self)
#     202 def _update_values(self):
# --> 203     self._simplify_threshold = mpl.rcParams['path.simplify_threshold']
#     204     self._should_simplify = (
#     205         self._simplify_threshold > 0 and
#     206         mpl.rcParams['path.simplify'] and
#     207         len(self._vertices) >= 128 and
#     208         (self._codes is None or np.all(self._codes <= Path.LINETO))
#     209     )
#
# File c:\Users\adity\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\_api\__init__.py:217, in caching_module_getattr.<locals>.__getattr__(name)
#     215 if name in props:
#     216     return props[name].__get__(instance)
# --> 217 raise AttributeError(
#     218     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'rcParams'

# %%
convertIMGtoCarray.convert_video_to_rgb332_frames("disint.gif", "animation")
# Out:
# Processing video with 14 frames, dimensions: 220x211
# Processed frame 1/14
# Processed frame 2/14
# Processed frame 3/14
# Processed frame 4/14
# Processed frame 5/14
# Processed frame 6/14
# Processed frame 7/14
# Processed frame 8/14
# Processed frame 9/14
# Processed frame 10/14
# Processed frame 11/14
# Processed frame 12/14
# Processed frame 13/14
# Processed frame 14/14
# Saved raw array data to animation_array.txt
# Successfully created header file: animation.h
# Total size: 649880 bytes

# %%
convertIMGtoCarray.convert_video_to_rgb332_bin_frames("dinit.mp4", "output_frames", max_frames=10, rotate_k=1)
